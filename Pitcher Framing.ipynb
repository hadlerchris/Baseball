# %% [markdown]
# Calculating the best pitch framer
#
# Methodolgy - Instead of using traditional framing methodolgies like comparing an exact location of a strike zone to where the pitch landed, I compare a pitch to its closest 50 pitches in terms of location to determine the probability of a ball being called a strike.
#
# Using the probabilities of pitches, we can compare if catchers are over/underperforming this average benchmark. For example, if the final result shows that Austin Hedges has a difference of 0.05. This means that for any given pitch, Hedges has a 5% higher chance of a strike being called than the average catcher. Pretty nice!

# %%
from pybaseball import statcast
import pandas as pd
from pybaseball import playerid_reverse_lookup
from tqdm import tqdm
import numpy as np

# %%
data_2021 = statcast(start_dt='2021-04-01', end_dt='2021-06-10')
# Out:
# This is a large query, it may take a moment to complete
# Completed sub-query from 2021-04-01 to 2021-04-06
# Completed sub-query from 2021-04-07 to 2021-04-12
# Completed sub-query from 2021-04-13 to 2021-04-18
# Completed sub-query from 2021-04-19 to 2021-04-24
# Completed sub-query from 2021-04-25 to 2021-04-30
# Completed sub-query from 2021-05-01 to 2021-05-06
# Completed sub-query from 2021-05-07 to 2021-05-12
# Completed sub-query from 2021-05-13 to 2021-05-18
# Completed sub-query from 2021-05-19 to 2021-05-24
# Completed sub-query from 2021-05-25 to 2021-05-30
# Completed sub-query from 2021-05-31 to 2021-06-05
# Completed sub-query from 2021-06-06 to 2021-06-10

# %%
data_2021 = data_2021[(data_2021['type'] != 'X') & ((data_2021['description'] == 'ball') | (data_2021['description'] == 'called_strike') )]

# %%
data_2021 = data_2021[(data_2021['plate_x'].notna()) & (data_2021['plate_z'].notna())]
data_2021.replace(to_replace ="S",
                 value =1, inplace=True)
data_2021.replace(to_replace ="B",
                 value =0, inplace=True)
data_2021.reset_index(inplace=True)

# %%
def closest_node(node, nodes):
    nodes = np.asarray(nodes)
    dist_2 = np.sum((nodes - node)**2, axis=1)
    return np.argsort(dist_2)[:50]

def mean_ball_strike(df, position):
    return df.iloc[closest_node(df['x_y'].iloc[position], df['x_y'].drop(position, axis=0).values.tolist())]['type'].mean()

def loop_impl(df):
    result = []
    for i in tqdm(range(len(df))):
        result.append(
          mean_ball_strike(df, i)
        )
    df2 = pd.concat([df, pd.DataFrame(result, columns=['str_pct'])], axis=1)
    return df2

# %%
data_2021['x_y'] = data_2021[['plate_x', 'plate_z']].values.tolist()

# %%
data_test = loop_impl(data_2021.head(10000))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [00:51<00:00, 193.08it/s]

# %%
data_test2 = data_test.groupby(['fielder_2.1']).filter(lambda x:len(x)>100)
data_test2['diff'] = data_test2['type'] - data_test2['str_pct']
framing = data_test2.groupby('fielder_2.1')['diff'].mean().sort_values()

# %%
# a list of mlbam ids
player_ids = framing.index.to_list()

# find the names of the players in player_ids, along with their ids from other data sources
data = playerid_reverse_lookup(player_ids, key_type='mlbam')
data.set_index('key_mlbam', inplace=True)
# Out:
# Gathering player lookup table. This may take a moment.

# %%
data_all = data.join(framing)
data_all.sort_values('diff')
# Out:
#            name_last name_first key_retro  key_bbref  key_fangraphs  \
# key_mlbam
# 608596        murphy        tom  murpt002  murphto04          13499
# 642851         wynns     austin  wynna001  wynnsau01          15271
# 543228         gomes        yan  gomey001  gomesya01           9627
# 519390          vogt    stephen  vogts001   vogtst01           5000
# 669257         smith       will  smitw003  smithwi05          19197
# 661388     contreras    william  contw002  contrwi02             -1
# 668670        rogers       jake  rogej004  rogerja03          19452
# 621512          nido      tomas  nidot001   nidoto01          13755
# 553882       narvaez       omar  narvo001  narvaom01          13338
# 624512       mcguire      reese  mcgur002  mcguire01          15674
# 592663      realmuto      j. t.  realj001  realmjt01          11739
# 488671         avila       alex  avila001  avilaal01           7476
# 571466      barnhart     tucker  barnt001  barnhtu01          10200
# 518735       grandal    yasmani  grany001  grandya01          11368
# 600474      severino      pedro  sevep001  severpe01          14523
# 608700      plawecki      kevin  plawk001  plaweke01          13807
# 575929     contreras    willson  contw001  contrwi01          11609
# 607732     stallings      jacob  stalj001  stallja01          13723
# 641680          heim      jonah  heimj001   heimjo01             -1
# 606992         haase       eric  haase001  haaseer01          14111
# 455117     maldonado     martin  maldm001  maldoma01           6887
# 668800       knizner     andrew  kniza001  kniznan01          19514
# 457763         posey     buster  poseb001  poseybu01           9166
# 605170      caratini     victor  carav001  caratvi01          14968
# 553869          diaz      elias  diaze005   diazel01          11680
# 624431       trevino       jose  trevj001  trevijo01          16725
# 680777       jeffers       ryan  jeffr002  jeffery01             -1
# 545358        stassi        max  stasm001  stassma01          10059
# 596142       sanchez       gary  sancg002  sanchga02          11442
# 521692         perez   salvador  peres002  perezsa02           7304
# 642336         mejia  francisco  mejif001  mejiafr01          16403
# 593590         rivas    webster  rivaw001        NaN             -1
# 608348         kelly     carson  kellc002  kellyca02          13620
# 506702          leon      sandy  leons001   leonsa01           5273
# 644433         tromp   chadwick  tromc001  trompch01             -1
# 572287        zunino       mike  zunim001  zuninmi01          13265
# 595751        alfaro      jorge  alfaj002  alfarjo01          12180
# 664731       higgins      p. j.  higgp001        NaN             -1
# 669221        murphy       sean  murps001  murphse01          19352
# 543877       vazquez  christian  vazqc001  vazquch01           9774
# 624513         nunez        dom  nuned001  nunezdo01          15055
# 543510        mccann      james  mccaj001  mccanja02          12859
# 605421         perez    michael  perem005  perezmi03          12977
# 608422         godoy       jose  godoj001        NaN             -1
# 595978        hedges     austin  hedga001  hedgeau01          12976
#
#            mlb_played_first  mlb_played_last      diff
# key_mlbam
# 608596               2015.0           2021.0 -0.076532
# 642851               2018.0           2021.0 -0.063846
# 543228               2012.0           2021.0 -0.053619
# 519390               2012.0           2021.0 -0.051667
# 669257               2019.0           2021.0 -0.048745
# 661388               2020.0           2021.0 -0.031728
# 668670               2019.0           2021.0 -0.029212
# 621512               2017.0           2021.0 -0.028281
# 553882               2016.0           2021.0 -0.024479
# 624512               2018.0           2021.0 -0.020388
# 592663               2014.0           2021.0 -0.015873
# 488671               2009.0           2021.0 -0.013600
# 571466               2014.0           2021.0 -0.008969
# 518735               2012.0           2021.0 -0.006954
# 600474               2015.0           2021.0 -0.005714
# 608700               2015.0           2021.0 -0.005588
# 575929               2016.0           2021.0 -0.005441
# 607732               2016.0           2021.0 -0.004821
# 641680               2020.0           2021.0 -0.002428
# 606992               2018.0           2021.0 -0.001869
# 455117               2011.0           2021.0 -0.001600
# 668800               2019.0           2021.0 -0.001250
# 457763               2009.0           2021.0 -0.000909
# 605170               2017.0           2021.0  0.001858
# 553869               2015.0           2021.0  0.003612
# 624431               2018.0           2021.0  0.004805
# 680777               2020.0           2021.0  0.008185
# 545358               2013.0           2021.0  0.009817
# 596142               2015.0           2021.0  0.011136
# 521692               2011.0           2021.0  0.014157
# 642336               2017.0           2021.0  0.015238
# 593590               2021.0           2021.0  0.017333
# 608348               2016.0           2021.0  0.018205
# 506702               2012.0           2021.0  0.018419
# 644433               2020.0           2021.0  0.020143
# 572287               2013.0           2021.0  0.020148
# 595751               2016.0           2021.0  0.021627
# 664731               2021.0           2021.0  0.025426
# 669221               2019.0           2021.0  0.033985
# 543877               2014.0           2021.0  0.036467
# 624513               2019.0           2021.0  0.043206
# 543510               2014.0           2021.0  0.043636
# 605421               2018.0           2021.0  0.044113
# 608422               2021.0           2021.0  0.044828
# 595978               2015.0           2021.0  0.053333
